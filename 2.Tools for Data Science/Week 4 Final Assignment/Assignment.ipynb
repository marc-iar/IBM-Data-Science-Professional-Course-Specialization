# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mihir Kudale__
# - Masters in Computer Applications Student

# %% [markdown]
# *I am interested in data science because I like this domain very much especially machine learning and would like to a data scientist.*

# %% [markdown]
# ### Calculate the sum of 1 plus 1

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# 1. Hello
# 2. Everyone

# %% [markdown]
# ____________________

# %% [markdown]
# - this
# - is
# - student
# - Grading

# %% [markdown]
#  | Student | Grade |
#  | ---   | ---  |
#  | Akshay Kamthe | 90 |
#  | Sameer Patil | 95 |

# %% [markdown]
# *I should study more*  - Akshay Kamthe
#
# *My score is good*  - Sameer Patil
